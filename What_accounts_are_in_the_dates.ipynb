# %%
#importing
import pandas as pd
import csv
import os
import matplotlib.pyplot as plt

# %%
#reading_the_file
file = "/Users/.../users.csv"
followers_df = pd.read_csv(file)
followers_df.head()
# Out:
#                     id               name         username  \
# 0  1246821218323501056             Wojtek   Wojtek27499293
# 1  1239224282439471105             Robert   Robert88869352
# 2  1246741639458181120     Maks Paczyński    MaksPaczynski
# 3  1164126350371905536  Kazimierz Drzazga  KazimierzDrzazg
# 4  1246809132314890242               Anna     Anna44985138
#
#                                                  bio          location  url  \
# 0                                                NaN               NaN  NaN
# 1                 Tylko prawa strona medalu/anty PO.               NaN  NaN
# 2                                    Po prostu Maks.               NaN  NaN
# 3  Wiceprezes Zarządu Morskich Portów Szczecin i ...  Szczecin, Polska  NaN
# 4                                                NaN               NaN  NaN
#
#      join_date join_time  tweets  following  followers  likes  media  private  \
# ...

# %%
#lets check specific dates
date = '14 Feb 2020'
cond = (followers_df['join_date'] == date)
selected = followers_df.loc[cond]
selected.sort_values(by="join_time")
# Out:
#                         id                                               name  \
# 10766  1228380676396855296                                           Karolina
# 10090  1228384628899241985                                               zuza
# 1399   1228398702928244737                               Artur ANTYsocjalista
# 9592   1228408952028831744                                             Damian
# 3900   1228410125494476801                                             hm....
# 9617   1228236566868512768  Mirek KANGÓR Pabian WARMIŃSKI TROLL BOJOWY #DU...
# 9444   1228420583169413120                                             Michał
# 2173   1228421262218801153                                          Bumblebee
# 9147   1228244384212307969                                             Joanna
# 9257   1228426503584731137                                             Michał
# 9276   1228429083471745032                                              basia
# ...
