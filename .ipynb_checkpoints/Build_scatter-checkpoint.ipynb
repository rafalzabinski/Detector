# %%
#IMPORTING
import pandas as pd
import csv
import os
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.dates import DayLocator, HourLocator, DateFormatter, drange

# %%
#FILE PATH
path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)
print(os.getcwd())
# Out:
# /Users/rafalzabinski/Desktop/TWINT/PROJEKTY

# %%
#READING FILE
file = "/Users/.../FOLLOWERS.csv"
followers_df = pd.read_csv(file)
#followers_df.dtypes

# %%
followers_df = followers_df.iloc[::-1]

# %%
followers_df.reset_index(inplace = True)

# %%
followers_df.index = np.arange(1, len(followers_df) + 1)

# %%
followers_df['join_date'] = pd.to_datetime(followers_df['join_date'])
#followers_df.dtypes

# %%
scatter = followers_df.drop(columns=['id', 'name', 'bio', 'location', 'url', 'join_time',
                           'tweets', 'following', 'followers', 'likes', 'media', 'private', 'verified', 'profile_image_url', 'background_image','index'])

# %%
scatter['following_position'] = scatter.index

# %%
from matplotlib.dates import DayLocator, HourLocator, DateFormatter, drange

# %%
plt.figure(figsize=(20,10))
plt.scatter(scatter["following_position"],scatter["join_date"].values, color="blue", s=0.5)
plt.savefig("duda.svg")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#sorting the data
top_dates = top_dates.sort_values(by= "join_date", ascending=True)

# %%
#plotting top join dates

top_dates.plot(kind = "barh", alpha=0.5,figsize=(8, 15))
plt.title("Most_Popular_Join_Dates")
plt.xlabel("Number of accounts created on a date")
plt.ylabel("Dates")
plt.savefig("Top_25_dates.png")
